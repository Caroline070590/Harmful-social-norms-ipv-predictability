# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("seydakaba/hofstede-cultural-dimensions-by-country")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/seydakaba/hofstede-cultural-dimensions-by-country?dataset_version_number=1...
# 100%|██████████████████████████████████████| 1.92k/1.92k [00:00<00:00, 1.09MB/s]
# Extracting files...
# Path to dataset files: /home/carolinealves/.cache/kagglehub/datasets/seydakaba/hofstede-cultural-dimensions-by-country/versions/1
